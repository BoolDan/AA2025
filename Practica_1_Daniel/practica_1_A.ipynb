# %% [markdown]
# Practica 1

# %%
#Importamos la librería pandas que nos va a permitir trabajar con datasets
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

filasorg = titanic.count()
titanic = titanic.drop_duplicates()
titanic = titanic.dropna(axis="rows", how="any")
filasdesp = titanic.count()

print(filasorg)
print(filasdesp)

titanic.reset_index()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64
#      index  PassengerId  Survived  Pclass  \
# 0        1            2         1       1
# 1        3            4         1       1
# 2        6            7         0       1
# 3       10           11         1       3
# 4       11           12         1       1
# ..     ...          ...       ...     ...
# 178    871          872         1       1
# 179    872          873         0       1
# 180    879          880         1       1
# 181    887          888         1       1
# 182    889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 178   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 179                           Carlsson, Mr. Frans Olof    male  33.0      0
# 180      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 181                       Graham, Miss. Margaret Edith  female  19.0      0
# 182                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 0        0  PC 17599  71.2833          C85        C
# 1        0    113803  53.1000         C123        S
# 2        0     17463  51.8625          E46        S
# 3        1   PP 9549  16.7000           G6        S
# 4        0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 178      1     11751  52.5542          D35        S
# 179      0       695   5.0000  B51 B53 B55        S
# 180      1     11767  83.1583          C50        C
# 181      0    112053  30.0000          B42        S
# 182      0    111369  30.0000         C148        C
#
# [183 rows x 13 columns]

# %% [markdown]
# Es importante limpiar los datasets antes de utilizarlos porque los datos de mala calidad pueden afectar negativamente el análisis y la precisión de los modelos. Los valores nulos pueden generar errores en cálculos o modelos de machine learning, ya que muchas técnicas no pueden manejarlos adecuadamente. Por otro lado, los datos duplicados pueden sesgar los resultados y hacer que ciertos valores tengan un peso mayor del que deberían. Al eliminar valores nulos y duplicados, se mejora la calidad de los datos, garantizando análisis más confiables y modelos más precisos.

# %%
#Limpiamos los cambios hechos al dataset
titanic.reset_index(drop=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 178          872         1       1
# 179          873         0       1
# 180          880         1       1
# 181          888         1       1
# 182          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 178   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 179                           Carlsson, Mr. Frans Olof    male  33.0      0
# 180      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 181                       Graham, Miss. Margaret Edith  female  19.0      0
# 182                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 0        0  PC 17599  71.2833          C85        C
# 1        0    113803  53.1000         C123        S
# 2        0     17463  51.8625          E46        S
# 3        1   PP 9549  16.7000           G6        S
# 4        0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 178      1     11751  52.5542          D35        S
# 179      0       695   5.0000  B51 B53 B55        S
# 180      1     11767  83.1583          C50        C
# 181      0    112053  30.0000          B42        S
# 182      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %% [markdown]
# 2. Antes de empezar, determina si hay algún atributo no nos va a resultar útil y por qué.
#
# ***Respuesta***
# Consideramos dos columnas como innecesarias para el dataset:
#     . Ticket: almacena el número de ticket que tenía el pasajero, este no es relevante debido a que no tiene sentido compararlo con ningún otro valor.
#     . Cabin: almacena el número de cabina de cada pasajero, no se considera un dato importante.

# %%
titanic.drop('Tickets')

# %% [markdown]
# 3. Relaciones entre atributos: dibuja diagramas de dispersión y calcula coeficientes de correlación. ¿Cuáles son los atributos que están más relacionados y qué podemos interpretar?

# %%
#Para dibujar un diagrama de dispersión utilizaremos la función pandas.DataFrame.plot.scatter
titanic.plot.scatter(x = "Pclass", y = "Fare")

#Para calcular los coeficientes de correlación utilizaremos la función pandas.DataFrame.corr
titanic.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.148495 -0.089136  0.030933 -0.083488 -0.051454
# Survived        0.148495  1.000000 -0.034542 -0.254085  0.106346  0.023582
# Pclass         -0.089136 -0.034542  1.000000 -0.306514 -0.103592  0.047496
# Age             0.030933 -0.254085 -0.306514  1.000000 -0.156162 -0.271271
# SibSp          -0.083488  0.106346 -0.103592 -0.156162  1.000000  0.255346
# Parch          -0.051454  0.023582  0.047496 -0.271271  0.255346  1.000000
# Fare            0.029740  0.134241 -0.315235 -0.092424  0.286433  0.389740
#
#                  Fare
# PassengerId  0.029740
# Survived     0.134241
# Pclass      -0.315235
# Age         -0.092424
# SibSp        0.286433
# Parch        0.389740
# Fare         1.000000

# %% [markdown]
# 4. Atributos numéricos:
#     a. Calcula media, desviación típica, valores mínimos, máximos, etc. de los atributos numéricos. Describe estos valores para cada variable.

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
titanic.mean(numeric_only=True)

# %%
titanic.std(numeric_only=True)

# %%
titanic.min(numeric_only=True)

# %%
titanic.max(numeric_only=True)

# %% [markdown]
# 5. Atributos categóricos:
#     a. Dibuja histogramas, diagramas de barras o de tartas para determinar las frecuencias de los valores de los atributos categóricos. Indica el número de valores distintos para cada atributo y el valor más frecuente para cada atributo. ¿Qué atributos están balanceados y cuáles no?

# %%
titanic.hist(figsize=(20,10), bins= 50)
titanic["Embarked"]

# %% [markdown]
# Como podemos ver en las gráficas de arriba los valores más balanceados son los de "Age" y "PassengerID" que representan la edad de los pasajeros y sus identifadores respectivamente, los que se encuentran más desbalanceados son "Pclass" y "Survived", que representan la clase en la que viajaban los pasajeros y aquellos que sobrevivieron al hundimiento respectivamente.
#
# Los valores máximos de cada atributo son los siguientes:
#     **PassengerId**:
#     **Survived**: 1.0
#     **Pclass**: 1.00
#     **Age**:
#     **SibSp**:
#     **Parch**:
#     **Fare**:

# %% [markdown]
# 6. Determina si hay outliers. Fíjate en las gráficas y descripciones que has empezado antes.

# %%
#Para poder sacar aquellos valores considerados "outliers" vamos a usar la libreria scipy.stats
from scipy import stats

threshold_z = 2 #Vamos a poner que la diferencia del valor frente a la media no puede ser superior a dos.

outlier_indices = np.where(np.abs(stats.zscore(titanic["PassengerId"])) > threshold_z)[0]
no_outliers = titanic.drop(outlier_indices)
print("Original DataFrame Shape:", titanic.shape)
print("DataFrame Shape after Removing Outliers:", no_outliers.shape)
# Out:
# Original DataFrame Shape: (183, 12)
# DataFrame Shape after Removing Outliers: (183, 12)

# %% [markdown]
# 7. Convierte los atributos categóricos en valores numéricos usando OneHotEncoder (o getdummies) y LabelEnconder. Observa las diferencias y discute cuál sería la mejor opción cuando el dataset sea usado en un modelo de IA.

# %%
from sklearn.preprocessing import OneHotEncoder #OneHotEncoder all the way
from sklearn.preprocessing import LabelEncoder

onehot = OneHotEncoder(handle_unknown='ignore')
label = LabelEncoder()

labelstoencode = ['']

titanic_label = label.fit_transform(titanic.columns)
titanic_onehot = onehot.fit_transform(titanic)

print(titanic_onehot)

# %%
from sklearn.preprocessing import Normalizer, StandardScaler

norm = Normalizer()
stand = StandardScaler(with_mean=False)

#titanic_norm_label = norm.fit_transform(titanic_label)
#titanic_stand_label = stand.fit_transform(titanic_label)

titanic_norm_one = norm.fit_transform(titanic_onehot)
titanic_stand_one = stand.fit_transform(titanic_onehot)


print(titanic_norm_one)
print(titanic_stand_one)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31508\1558270657.py in ?()
#       5
#       6 #titanic_norm_label = norm.fit_transform(titanic_label)
#       7 #titanic_stand_label = stand.fit_transform(titanic_label)
#       8
# ----> 9 titanic_norm_one = norm.fit_transform(titanic)
#      10 titanic_stand_one = stand.fit_transform(titanic_onehot)
#      11
#      12
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
#    1101             return self.fit(X, y, **fit_params).transform(X)
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y)
#    2078         -------
#    2079         self : object
#    2080             Fitted transformer.
#    2081         """
# -> 2082         self._validate_data(X, accept_sparse="csr")
#    2083         return self
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# c:\Users\danid\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# c:\Users\danid\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
